# %%
#Dependencies and Setup
import hvplot.pandas
import pandas as pd
import requests
import gmaps
import cartopy.crs as ccrs
import geoviews as gv # noqa
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Input In [9], in <cell line: 6>()
#       4 import requests
#       5 import gmaps
# ----> 6 import cartopy.crs as ccrs
#       7 import geoviews as gv
#
# ModuleNotFoundError: No module named 'cartopy'

# %%
# Load the CSV file created in Part 1 into a Pandas DataFrame
city_data_df = pd.read_csv("C:\Data Analystics\Module6\cities.csv")

city_data_df.index.values
#city_data_df_clean = city_data_df.drop(city_data_df.index[0])

city_data_df_clean = city_data_df[city_data_df["Humidity"]>0]

# Display sample data
city_data_df_clean.head()
# Out:
#    City_ID         City      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 1        1      rikitea -23.1203 -134.9692     71.87     71.87         100
# 2        2  new norfolk -42.7826  147.0587     62.92     56.91          99
# 3        3      mataura -46.1927  168.8643     58.48     58.48          89
# 4        4       mangit  40.5971   70.9607     46.20     46.20          81
# 5        5      peleduy  59.6289  112.7406      0.39      0.39          78
#
#    Wind Speed Country        Date
# 1        9.06      PF  1668918726
# 2       10.00      AU  1668918863
# 3        1.66      NZ  1668918727
# 4        2.46      UZ  1668918552
# 5        1.41      RU  1668918864

# %%
pip list
# Out:
# Package                       Version
# ----------------------------- --------------------
# aiohttp                       3.8.1
# aiosignal                     1.2.0
# alabaster                     0.7.12
# anaconda-client               1.9.0
# anaconda-navigator            2.1.4
# anaconda-project              0.10.2
# anyio                         3.5.0
# appdirs                       1.4.4
# argon2-cffi                   21.3.0
# argon2-cffi-bindings          21.2.0
# arrow                         1.2.2
# astroid                       2.6.6
# astropy                       5.0.4
# asttokens                     2.0.5
# async-timeout                 4.0.1
# atomicwrites                  1.4.0
# attrs                         21.4.0
# Automat                       20.2.0
# autopep8                      1.6.0
# Babel                         2.9.1
# backcall                      0.2.0
# backports.functools-lru-cache 1.6.4
# backports.tempfile            1.0
# ...

# %%
map_plot = city_data_df_clean.hvplot.points(
    "Lng", 
    "Lat", 
    geo = True, 
    size = "Humidity",
    scale = 1,
    color = "City",
    alpha = 0.5,
    tiles = "OSM",
    frame_width = 700,
    frame_height = 500)
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# File ~\anaconda3\lib\site-packages\hvplot\util.py:182, in process_crs(crs)
#     181 try:
# --> 182     import cartopy.crs as ccrs
#     183     import geoviews as gv # noqa
#
# ModuleNotFoundError: No module named 'cartopy'
#
# During handling of the above exception, another exception occurred:
#
# ImportError                               Traceback (most recent call last)
# Input In [11], in <cell line: 1>()
# ----> 1 map_plot = city_data_df_clean.hvplot.points(
#       2     "Lng",
#       3     "Lat",
#       4     geo = True,
#       5     size = "Humidity",
#       6     scale = 1,
#       7     color = "City",
#       8     alpha = 0.5,
#       9     tiles = "OSM",
#      10     frame_width = 700,
#      11     frame_height = 500)
#
# ...
